# %% [markdown]
# Image Data Processing

# %%
# Getting the image with the help of web get
# !wget 'https://img.freepik.com/premium-photo/cat-with-open-mouth-with-blur-background_802140-13680.jpg'
# Out:
# --2025-08-08 03:12:09--  https://img.freepik.com/premium-photo/cat-with-open-mouth-with-blur-background_802140-13680.jpg
# Resolving img.freepik.com (img.freepik.com)... 23.61.246.213, 23.61.246.212, 2600:140a:1000:d::17da:ef18, ...
# Connecting to img.freepik.com (img.freepik.com)|23.61.246.213|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 43320 (42K) [image/jpeg]
# Saving to: ‘cat-with-open-mouth-with-blur-background_802140-13680.jpg’
#
# cat-with-open-mouth 100%[===================>]  42.30K   162KB/s    in 0.3s
#
# 2025-08-08 03:12:10 (162 KB/s) - ‘cat-with-open-mouth-with-blur-background_802140-13680.jpg’ saved [43320/43320]

# %% [markdown]
# Libraries that can be used for image processing:
# 1. matplotlib.image
# 2. Pillow
# 3. OpenCV (cv2)

# %%
#importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
# loading an image through matplotlib.image module
img = mpimg.imread('/content/cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
# for gettiing dimension
print(img.shape)
# Out:
# (351, 626, 3)

# %% [markdown]
# here (351, 626) represents the dimension and 3 represents the colour channel

# %%
print(img) # image getting converted into numy array
# Out:
# [[[140 165 143]
#   [140 165 143]
#   [142 167 145]
#   ...
#   [141 109  88]
#   [140 109  88]
#   [140 109  88]]
#
#  [[139 164 142]
#   [140 165 143]
#   [141 166 144]
#   ...
#   [141 109  88]
#   [140 109  88]
#   [140 109  88]]
#
#  [[138 163 141]
#   [139 164 142]
#   [140 165 143]
#   ...
#   [140 109  88]
#   [140 109  88]
#   [140 109  88]]
#
#  ...
#
#  [[ 28  41  49]
#   [ 29  42  50]
#   [ 31  44  53]
#   ...
#   [ 43  42  40]
#   [ 42  40  41]
#   [ 42  40  41]]
#
#  [[ 25  38  46]
#   [ 26  39  47]
#   [ 28  41  50]
#   ...
#   [ 38  37  35]
#   [ 39  37  38]
#   [ 39  37  38]]
#
#  [[ 25  36  42]
#   [ 26  37  43]
#   [ 27  37  46]
#   ...
#   [ 36  35  33]
#   [ 37  35  36]
#   [ 37  35  36]]]

# %%
# converting numpy array into image
img_plot = plt.imshow(img)
plt.show()

# %% [markdown]
# Resizing the image using pillow library

# %%
from PIL import Image

# %%
img = Image.open('/content/cat.jpg')
img_resized = img.resize((200,200))

# %%
img_resized.save('/content/cat_resized.jpg')

# %%
#display the iimaghe from numpy array
img_res = mpimg.imread('/content/cat_resized.jpg')
img_res_plot = plt.imshow(img_res)
plt.show()

# %%
#shape of the image
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# Convert RGB images to Grayscale images using OpenCV

# %%
#importing OpenCV Library
import cv2

# %%
img = cv2.imread('/content/cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (351, 626, 3)

# %%
grayscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (351, 626)

# %% [markdown]
# cv2.imshow() will display the image but this will not be allowed in google collab.
#
# for displaying the image in google colab we use -
#
# **from google.colab.patches import cv2_imshow**

# %%
from google.colab.patches import cv2_imshow

# %%
#display the image
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=626x351>

# %%
# saving the garyscale image
cv2.imwrite('/content/cat_grayscale.jpg', grayscale_image) # here 'cv2' is a library , 'imwrite' is a function , 'cat_grayscale' is the name of image , 'graysacle' what type of image we are saving
# Out:
# True
